# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %% [markdown]
# resolvendo tarefa 1 - Exercício 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os

os.getcwd()
print(os.getcwd())
#df = pd.read_csv('.ipynb_checkpoints/SINASC_RO_2019.csv')
#df = pd.read_csv('SINASC_RO_2019.csv')


df.head()
# Out:
# C:\Users\DELL\Documents\Hd-arquivos\cursos-e-pós\Curso-EBAC-cientista-de-Dados\EBAC-Cientista-de-dados\Curso\projetos\parte-07-descritivas-I
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %% [markdown]
# Resolvendo tarefa 1 - Exercicio 2

# %%
df['APGAR1'].value_counts().sort_index().plot.bar()
plt.show()

df['APGAR5'].value_counts().sort_index().plot.bar()
plt.show()

df['SEXO'].value_counts().plot.bar()
plt.show()

df['GESTACAO'].value_counts().plot.bar()
plt.show()

df['ESTCIVMAE'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %% [markdown]
# Resolvendo tarefa 1 - Exercicio 3

# %%
media_apgar = df.groupby('CONSULTAS')['APGAR5'].mean()

media_apgar.plot.bar()

plt.show()

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %% [markdown]
# Resolvendo tarefa 1 - Exercicio 4

# %%
fig, axes = plt.subplots(2,2, figsize=(12,10))

sns.countplot(ax=axes[0,0], x='SEXO', data=df)

sns.countplot(ax=axes[0,1], x='GESTACAO', data=df)

sns.countplot(ax=axes[1,0], x='ESTCIVMAE', data=df)

sns.countplot(ax=axes[1,1], x='CONSULTAS', data=df)

plt.tight_layout()

plt.show()
